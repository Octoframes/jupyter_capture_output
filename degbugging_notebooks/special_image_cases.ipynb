# %%
import jupyter_capture_output

from IPython.core.display import HTML
from IPython.display import display
from IPython.display import Image
# Out:
# Jupyter Capture Output v0.0.9

# %%
# %%capture_img --path "matplotlib_dog.png"
# # ✅✅✅
# import matplotlib.pyplot as plt
# dog = plt.imread('../assets/cute_dog.jpg')
# plt.imshow(dog)
# plt.axis("off")
# plt.show()
# Out:
# Output saved by creating file at matplotlib_dog.png.

# %%
# %%capture_img --path "local.png"
# # ❌❌❌ this does not work
# Image("../assets/cute_dog.jpg",embed=False, width=300)
# Out:
# Output saved by creating file at local.png.
# <img src="None" width="300"/>

# %%
# %%capture_img --path "local.png"
# # ❌❌❌
# Image("../assets/cute_dog.jpg",embed=True, width=300)
# Out:
# Output saved by creating file at local.png.

# %%
# %%capture_img --path "dog_web.png"
# # ❌❌❌
# Image("https://raw.githubusercontent.com/Octoframes/jupyter_capture_output/f8968519e9ae161c56f126f8d2cf155795fdde86/assets/cute_dog.jpg", width=300)
# Out:
# Output saved by creating file at dog_web.png.

# %%
from pathlib import Path
Path("matplotlib_dog.png").unlink()
