# %%
import jupyter_capture_output
# Out:
# Jupyter Capture Output v0.0.6

# %%
# %%capture_text --path "cap/foo.txt"
# print("Hello World")
# Out:
# Hello World

# %%
# %%capture_video -p "cap/video.mp4"
# from IPython.display import Video
# Video('assets/doppler_effect.mp4', width=300)
# Out:
# <video src="assets/doppler_effect.mp4" controls  width="300" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%capture_img --path "cap/foo.png"
# import matplotlib.pyplot as plt
# plt.plot([1,2],[10,20])
# plt.show()

# %%
# %%capture_img  --path "cap/foo.jpg" --compression 50
# plt.plot([1,2],[10,20], color = "r")
# plt.show()

# %%
# %%capture_img --path "cap/img1.png cap/img2.png"
# plt.plot([1,2],[10,20], color = "g")
# plt.show()
# plt.plot([3,4],[-10,-20],color = "g")
# plt.show()

# %%
from pathlib import Path
Path("cap/foo.txt").unlink()
Path("cap/video.mp4").unlink()
Path("cap/foo.png").unlink()
Path("cap/foo.jpg").unlink()
Path("cap/img1.png").unlink()
Path("cap/img2.png").unlink()
